# %%
import pandas as pd
import json
import os
import requests
from datetime import datetime, timezone
import matplotlib as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score
import numpy as np
import statsmodels.api as sms
from tensorflow.keras.layers import Dropout

# %%
url = "https://merolagani.com/handlers/TechnicalChartHandler.ashx?type=get_advanced_chart&symbol=ALICL&resolution=1D&rangeStartDate=1642411546&rangeEndDate=1770545453&from=&isAdjust=1&currencyCode=NPR"
response = requests.get(url)
data = response.json()


with open("ALICL_Feb.json", "w") as f:
    json.dump(data, f)

# %%
companies = ["/content/ALICL_Feb.json"]

for symbol in companies:
    with open(f"{symbol}", 'r') as f:
        data = json.load(f)
        print(data)
    dates = [datetime.fromtimestamp(ts, tz=timezone.utc).strftime('%Y-%m-%d') for ts in data['t']]
    df=pd.DataFrame({
    "Date":dates,
    "Open":data['o'],
    "Close":data['c'],
    "High":data['h'],
    "Low":data['l'],
    "Volume":data['v']

})
    csv_filename = os.path.basename(symbol).replace('.json', '.csv')
    print(csv_filename)
    df.to_csv(csv_filename,index=False)
    print(f"{csv_filename}Feb_created")
# Out:
# {'t': [1642452300, 1642538700, 1642625100, 1642711500, 1642970700, 1643057100, 1643143500, 1643229900, 1643316300, 1643575500, 1643661900, 1643748300, 1643921100, 1644180300, 1644266700, 1644353100, 1644439500, 1644525900, 1644785100, 1644871500, 1644957900, 1645044300, 1645130700, 1645389900, 1645476300, 1645562700, 1645649100, 1645735500, 1645994700, 1646081100, 1646253900, 1646599500, 1646685900, 1646858700, 1646945100, 1647204300, 1647290700, 1647377100, 1647463500, 1647809100, 1647895500, 1647981900, 1648068300, 1648154700, 1648413900, 1648500300, 1648586700, 1648673100, 1648759500, 1649018700, 1649105100, 1649191500, 1649277900, 1649364300, 1649709900, 1649796300, 1649882700, 1650228300, 1650314700, 1650401100, 1650487500, 1650573900, 1650833100, 1650919500, 1651005900, 1651092300, 1651178700, 1651524300, 1651697100, 1651783500, 1652042700, 1652129100, 1652215500, 1652301900, 1652388300, 1652820300, 1652906700, 1652993100, 1653079500, 1653338700, 1653425100, 1653511500, 1653597900, 1653684300, 1653943500, 1654029900, 1654116300, 1654202700, 1654289100, 1654548300, 1654634700, 1654721100, 1654807500, 1654893900, 1655153100, 1655239500, 1655325900, 1655412300, 1655498700, 1655671500, 1655757900, 1655844300, 1655930700, 1656017100, 1656103500, 1656276300, 1656362700, 1656449100, 1656535500, 1656621900, 1656708300, 1656881100, 1656967500, 1657053900, 1657140300, 1657226700, 1657313100, 1657572300, 1657658700, 1657745100, 1657831500, 1657917900, 1658090700, 1658177100, 1658263500, 1658349900, 1658436300, 1658522700, 1658695500, 1658781900, 1658868300, 1658954700, 1659041100, 1659127500, 1659300300, 1659386700, 1659473100, 1659559500, 1659645900, 1659732300, 1659905100, 1659991500, 1660077900, 1660164300, 1660250700, 1660509900, 1660596300, 1660682700, 1660769100, 1660855500, 1661114700, 1661201100, 1661287500, 1661373900, 1661460300, 1661546700, 1661719500, 1661805900, 1661892300, 1661978700, 1662064380, 1662151500, 1662324300, 1662410700, 1662497100, 1662583500, 1662669900, 1662929100, 1663015500, 1663101900, 1663188300, 1663274700, 1663361100, 1663533900, 1663706700, 1663793100, 1663879500, 1664138700, 1664311500, 1664397900, 1664484300, 1665348300, 1665434700, 1665521100, 1665607500, 1665693900, 1665953100, 1666039500, 1666212300, 1666298700, 1666557900, 1667249100, 1667335500, 1667421900, 1667508300, 1667767500, 1667853900, 1667940300, 1668026700, 1668113100, 1668372300, 1668458700, 1668545100, 1668631500, 1668717900, 1669149900, 1669236300, 1669322700, 1669581900, 1669668300, 1669754700, 1669841100, 1669927500, 1670186700, 1670273100, 1670359500, 1670445900, 1670791500, 1670877900, 1670964300, 1671050700, 1671137100, 1671396300, 1671482700, 1671569100, 1671655500, 1671741900, 1672087500, 1672173900, 1672260300, 1672346700, 1672605900, 1672692300, 1672778700, 1672865100, 1672951500, 1673210700, 1673297100, 1673383500, 1673556300, 1673988300, 1674074700, 1674161100, 1674506700, 1674593100, 1674679500, 1674765900, 1675025100, 1675111500, 1675197900, 1675284300, 1675370700, 1675629900, 1675716300, 1675802700, 1675889100, 1675975500, 1676234700, 1676407500, 1676493900, 1676580300, 1676925900, 1677098700, 1677185100, 1677444300, 1677530700, 1677617100, 1677703500, 1677789900, 1678049100, 1678221900, 1678394700, 1678653900, 1678740300, 1678826700, 1678913100, 1678999500, 1679258700, 1679345100, 1679517900, 1679604300, 1679863500, 1679949900, 1680036300, 1680122700, 1680209100, 1680468300, 1680554700, 1680641100, 1680727500, 1680813900, 1681073100, 1681159500, 1681245900, 1681332300, 1681418700, 1681677900, 1681764300, 1681850700, 1681937100, 1682023500, 1682282700, 1682369100, 1682455500, 1682541900, 1682628300, 1682887500, 1683060300, 1683146700, 1683233100, 1683492300, 1683578700, 1683665100, 1683751500, 1683837900, 1684097100, 1684183500, 1684269900, 1684356300, 1684442700, 1684701900, 1684788300, 1684874700, 1684961100, 1685306700, 1685479500, 1685565900, 1685652300, 1685911500, 1685997900, 1686084300, 1686170700, 168625710 ...
# ALICL_Feb.csv
# ALICL_Feb.csvFeb_created

# %%
df = pd.read_csv("ALICL_Feb.csv")
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index('Date')
print(len(df))
# Out:
# 942

# %%
df.head()
# Out:
#               Open   Close    High     Low   Volume
# Date
# 2022-01-17  575.00  571.75  579.05  564.02  48327.0
# 2022-01-18  575.00  572.57  579.05  567.28  60928.0
# 2022-01-19  583.41  567.69  583.41  562.00  29278.0
# 2022-01-20  568.91  573.37  577.03  559.60  37239.0
# 2022-01-23  581.09  572.96  586.78  572.68  72785.0

# %%
df.tail()
# Out:
#              Open  Close   High    Low   Volume
# Date
# 2026-02-02  481.9  479.0  482.0  475.0  34706.0
# 2026-02-03  475.0  477.0  482.7  474.3  26671.0
# 2026-02-04  467.5  474.1  480.5  467.5  25539.0
# 2026-02-05  483.0  480.0  483.0  475.0  35987.0
# 2026-02-08  486.0  479.9  489.0  477.3  49511.0

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
results = seasonal_decompose(df['Close'], model='additive', period=30)
results.plot()

# %%
def plot_graph(figsize, df_to_plot, column_name):
    # df_to_plot is already assumed to have 'Date' as its index
    df_to_plot = df_to_plot.sort_index()

    plt.figure(figsize=figsize)
    plt.plot(df_to_plot.index, df_to_plot[column_name], label=column_name)
    plt.title(f"ASIAN LIFE {column_name} Over Time")
    plt.xlabel("Date")
    plt.ylabel(column_name)
    plt.legend()
    plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(df['Open'], label='Open Price')
plt.plot(df['Close'], label='Close Price')
plt.plot(df['High'], label='High Price')
plt.plot(df['Low'], label='Low Price')
plt.plot(df['Volume'], label='Volume')

# %%
df['MA_10'] = df['Close'].rolling(10).mean()
df['MA_20'] = df['Close'].rolling(20).mean()

# %%
print(df.isna().sum())
# Out:
# Open       0
# Close      0
# High       0
# Low        0
# Volume     0
# MA_10      9
# MA_20     19
# dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(df['Close'], label='Close Price')
plt.plot(df['MA_10'], label='MA 10')
plt.legend()
plt.title("Close Price vs 10-day Moving Average")
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['Close'], label='Close Price')
plt.plot(df['MA_20'], label='MA 20')
plt.legend()
plt.title("Close Price vs 20-day Moving Average")
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# %%
len(df)
# Out:
# 942

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 942 entries, 2022-01-17 to 2026-02-08
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    942 non-null    float64
#  1   Close   942 non-null    float64
#  2   High    942 non-null    float64
#  3   Low     942 non-null    float64
#  4   Volume  942 non-null    float64
#  5   MA_10   933 non-null    float64
#  6   MA_20   923 non-null    float64
# dtypes: float64(7)
# memory usage: 58.9 KB

# %%
def plot_graph(figsize, df_to_plot, column_name):

    plt.figure(figsize=figsize)
    plt.plot(df_to_plot.index, df_to_plot[column_name], label=column_name)
    plt.title(f"ASIAN LIFE {column_name} Over Time")
    plt.xlabel("Date")
    plt.ylabel(column_name)
    plt.legend()
    plt.show()

# %%
import matplotlib.pyplot as plt
plot_graph((10, 5), df, "Close")

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import random
import os
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping

# %%
seed = 42
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)
os.environ["PYTHONHASHSEED"] = str(seed)

# %%
df = df[['Open','High','Low','Close','Volume']].copy()
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)

# stabilize volume
df['Volume'] = np.log1p(df['Volume'])

# %%
features = df[['Open','High','Low','Close','Volume']].values

# %%
window = 60
split = int(len(features) * 0.8)

train_raw = features[:split]
test_raw  = features[split - window:]

# %%
scaler_X = MinMaxScaler()
train_scaled = scaler_X.fit_transform(train_raw)
test_scaled  = scaler_X.transform(test_raw)

scaler_y = MinMaxScaler()
scaler_y.fit(train_raw[:, 3].reshape(-1, 1))
# Out:
# MinMaxScaler()

# %%
def create_sequences(data, window):
    X, y = [], []
    for i in range(window, len(data)):
        X.append(data[i-window:i])
        y.append(data[i, 3])  # Close
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.float32).reshape(-1,1)

# %%
X_train, y_train = create_sequences(train_scaled, window)
X_test, y_test   = create_sequences(test_scaled, window)

# %%
model_ohlcv = Sequential([
LSTM(128, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.2),
    LSTM(64),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dense(1)
])

model_ohlcv.compile(optimizer=tf.keras.optimizers.Adam(0.001), loss='mse')
model_ohlcv.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# Model: "sequential_22"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_45 (LSTM)                  │ (None, 60, 128)        │        68,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_47 (Dropout)            │ (None, 60, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_46 (LSTM)                  │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_48 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_45 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_46 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 120,129 (469.25 KB)
#  Trainable params: 120,129 (469.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stop = EarlyStopping(patience=10, restore_best_weights=True)

history = model_ohlcv.fit(
  X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_test, y_test),
    verbose=1
)
# Out:
# Epoch 1/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.1353 - val_loss: 0.0086
# Epoch 2/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0152 - val_loss: 0.0054
# Epoch 3/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0083 - val_loss: 0.0020
# Epoch 4/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0066 - val_loss: 0.0020
# Epoch 5/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0055 - val_loss: 0.0019
# Epoch 6/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0053 - val_loss: 0.0023
# Epoch 7/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0047 - val_loss: 0.0028
# Epoch 8/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0041 - val_loss: 0.0019
# Epoch 9/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0045 - val_loss: 0.0021
# Epoch 10/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0048 - val_loss: 0.0018
# Epoch 11/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0041 - val_loss: 0.0020
# Epoch 12/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0045 - val_loss: 0.0020
# Epoch 13/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0036 - val_loss: 0.0020
# Epoch 14/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0041 - val_loss: 0.0018
# Epoch 15/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0036 - val_loss: 0.0017
# Epoch 16/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0037 - val_loss: 0.0017
# Epoch 17/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0033 - val_loss: 0.0018
# Epoch 18/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0042 - val_loss: 0.0019
# Epoch 19/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0035 - val_loss: 0.0016
# Epoch 20/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0038 - val_loss: 0.0017
# Epoch 21/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0034 - val_loss: 0.0016
# Epoch 22/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0032 - val_loss: 0.0023
# Epoch 23/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0039 - val_loss: 0.0016
# Epoch 24/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0030 - val_loss: 0.0020
# Epoch 25/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0034 - val_loss: 0.0015
# Epoch 26/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0032 - val_loss: 0.0015
# Epoch 27/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0031 - val_loss: 0.0015
# Epoch 28/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0032 - val_loss: 0.0015
# Epoch 29/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0030 - val_loss: 0.0015
# Epoch 30/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0032 - val_loss: 0.0014
# Epoch 31/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0028 - val_loss: 0.0014
# Epoch 32/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0033 - val_loss: 0.0018
# Epoch 33/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0028 - val_loss: 0.0014
# Epoch 34/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0028 - val_loss: 0.0013
# Epoch 35/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0029 - val_loss: 0.0014
# Epoch 36/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0029 - val_loss: 0.0013
# Epoch 37/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 38/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 39/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - val_loss: 0.0014
# Epoch 40/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0026 - val_loss: 0.0012
# Epoch 41/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0025 - val_loss: 0.0014
# Epoch 42/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0026 - val_loss: 0.0013
# Epoch 43/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0025 - val_loss: 0.0012
# Epoch 44/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0028 - val_loss: 0.0013
# Epoch 45/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0023 - val_loss: 0.0014
# Epoch 46/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0024 - val_loss: 0.0012
# Epoch 47/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 48/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0026 - val_loss: 0.0012
# Epoch 49/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0024 - val_loss: 0.0011
# Epoch 50/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 51/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 52/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0026 - val_loss: 0.0012
# Epoch 53/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0021 - val_loss: 0.0010
# Epoch 54/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 55/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0022 - val_loss: 0.0010
# Epoch 56/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 57/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 58/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0020 - val_loss: 0.0010
# Epoch 59/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0020 - val_loss: 9.5587e-04
# Epoch 60/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0021 - val_loss: 0.0010
# Epoch 61/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0023 - val_loss: 0.0011
# Epoch 62/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0020 - val_loss: 9.2644e-04
# Epoch 63/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0018 - val_loss: 9.0576e-04
# Epoch 64/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0020 - val_loss: 9.9857e-04
# Epoch 65/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 66/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0023 - val_loss: 8.4321e-04
# Epoch 67/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0021 - val_loss: 0.0010
# Epoch 68/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0018 - val_loss: 8.8445e-04
# Epoch 69/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0019 - val_loss: 8.4638e-04
# Epoch 70/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0017 - val_loss: 8.2557e-04
# Epoch 71/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0018 - val_loss: 8.2638e-04
# Epoch 72/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0017 - val_loss: 7.8243e-04
# Epoch 73/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0016 - val_loss: 7.9235e-04
# Epoch 74/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 75/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0017 - val_loss: 8.2143e-04
# Epoch 76/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0015 - val_loss: 7.7123e-04
# Epoch 77/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0017 - val_loss: 7.4669e-04
# Epoch 78/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0016 - val_loss: 8.7654e-04
# Epoch 79/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0015 - val_loss: 9.7161e-04
# Epoch 80/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0018 - val_loss: 8.1167e-04
# Epoch 81/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0016 - val_loss: 8.3380e-04
# Epoch 82/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0016 - val_loss: 7.6509e-04
# Epoch 83/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0015 - val_loss: 7.3025e-04
# Epoch 84/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0016 - val_loss: 7.1160e-04
# Epoch 85/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0014 - val_loss: 7.0421e-04
# Epoch 86/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0016 - val_loss: 7.6881e-04
# Epoch 87/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0016 - val_loss: 7.0170e-04
# Epoch 88/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0015 - val_loss: 6.9033e-04
# Epoch 89/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0014 - val_loss: 7.7481e-04
# Epoch 90/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0015 - val_loss: 6.8621e-04
# Epoch 91/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0015 - val_loss: 6.6941e-04
# Epoch 92/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0016 - val_loss: 7.0548e-04
# Epoch 93/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0015 - val_loss: 7.3870e-04
# Epoch 94/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0014 - val_loss: 6.5229e-04
# Epoch 95/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0014 - val_loss: 6.5969e-04
# Epoch 96/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0014 - val_loss: 6.5161e-04
# Epoch 97/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0014 - val_loss: 6.5491e-04
# Epoch 98/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 99/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0016 - val_loss: 8.0176e-04
# Epoch 100/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0015 - val_loss: 7.0320e-04

# %%
pred_scaled = model_ohlcv.predict(X_test)

if pred_scaled.ndim == 3:
    pred_scaled = pred_scaled[:, -1, :]

pred = scaler_y.inverse_transform(pred_scaled)
actual = scaler_y.inverse_transform(y_test)

rmse = np.sqrt(mean_squared_error(actual, pred))
mae = mean_absolute_error(actual, pred)

print("RMSE for ASIAN:", rmse)
print("MAE for  ASIAN:", mae)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# RMSE for ASIAN: 8.115532156464983
# MAE for  ASIAN: 5.771730422973633

# %%
import plotly.graph_objects as go
import numpy as np

actual_flat = actual.flatten()
pred_flat = pred.flatten()

fig = go.Figure()

fig.add_trace(
    go.Scatter(
        y=actual_flat,
        mode="lines",
        name="Actual",
        line=dict(width=2)
    )
)

fig.add_trace(
    go.Scatter(
        y=pred_flat,
        mode="lines",
        name="Predicted",
        line=dict(
            width=2,
            shape="spline"
        )
    )
)

fig.update_layout(
    title="LSTM with OHLCV — Actual vs Predicted For ASIAN LIFE",
    xaxis_title="Time",
    yaxis_title="Price",
    hovermode="x unified",
    template="plotly_white"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d47bb9d3-479d-426b-8095-f34ab8da706a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d47bb9d3-479d-426b-8095-f34ab8da706a")) {                    Plotly.newPlot(                        "d47bb9d3-479d-426b-8095-f34ab8da706a",                        [{"line":{"width":2},"mode":"lines","name":"Actual","y":[535.41,537.38,536.31,532.29004,536.98,536.05,536.51,531.27997,532.85,527.24,520.18,520.26996,519.0,519.11,519.54,520.57,521.85,520.64,519.76996,529.27997,521.69,520.5,523.77997,518.87,517.16003,512.46,512.46,517.08,525.04,527.77,522.2,515.54,515.26,511.44,502.0,503.02,498.11,491.11002,484.25,477.75,481.6,484.35,481.9,483.21,482.63,482.61,480.86002,482.94,482.50998,480.84998,480.72,476.5,477.49997,476.63,479.16998,479.6,484.16998,499.68,519.76996,500.12,499.75,499.41,499.64,499.71,499.79,490.37997,491.91998,498.36002,513.39996,518.3,519.91003,541.77,539.9,537.8,533.48,527.14,526.63,522.87,516.58,505.3,505.22998,499.67,498.2,499.90997,491.68002,487.88,490.97998,491.78,485.11002,483.55,484.93,486.0,488.57,486.1,491.27,491.03,502.27997,490.37,485.65,485.24,480.94998,481.05,480.24,479.37,472.22,462.8,480.46,477.99997,475.0,477.99997,473.0,466.40002,453.99997,461.80002,449.4,459.99997,452.0,447.99997,447.99997,447.0,445.6,463.1,459.0,476.99997,499.0,500.99997,487.0,474.9,473.2,468.2,464.0,467.80002,465.0,457.19998,452.5,450.0,451.0,451.0,447.99997,465.69998,493.8,493.8,491.0,486.0,482.9,479.5,473.4,465.0,459.99997,459.99997,465.0,464.4,464.5,461.9,465.0,468.2,469.5,464.8,461.6,456.9,456.0,457.0,468.5,464.5,467.80002,465.49997,461.9,465.99997,465.0,465.0,471.9,471.99997,476.0,473.7,480.7,489.99997,487.69998,488.0,491.5,488.4,480.2,476.99997,476.99997,473.0,479.0,476.99997,474.1,480.0,479.9],"type":"scatter"},{"line":{"shape":"spline","width":2},"mode":"lines","name":"Predicted","y":[537.4403,528.8062,529.01544,528.8013,526.5609,528.1044,530.301,532.85693,525.5112,524.694,523.98865,524.0155,515.2581,513.96484,515.98566,517.5005,515.9202,518.78864,514.5131,514.7242,520.40216,519.3663,523.27704,517.7126,512.3738,510.88583,511.75272,510.88678,510.57068,515.4251,526.2356,522.93536,516.9403,512.1278,508.66678,508.3256,502.12988,493.98285,488.26077,484.87204,480.85333,479.06857,484.41846,482.98932,477.79138,475.59317,479.56808,477.0124,476.49588,478.6353,481.74176,473.87234,472.65524,473.442,477.30835,472.7695,473.38504,476.6861,490.1601,513.1961,508.10153,495.66455,489.5188,493.5529,494.71472,499.7395,495.72095,491.52536,497.00894,505.43506,516.7068,514.5215,527.91486,534.8995,534.46185,530.51917,522.8361,522.4206,518.8371,514.20856,505.83847,501.11697,498.16113,493.8864,492.5654,493.02444,487.07098,487.49142,485.67462,485.11563,480.15027,481.52823,479.98383,481.21762,482.57025,483.17123,483.80997,493.1176,491.58102,484.4198,480.39697,480.41202,478.19247,476.52634,474.15903,471.66174,455.56442,470.21454,477.40903,473.928,472.36703,469.85934,467.70773,455.43707,459.58023,456.43762,455.51538,450.10074,445.81183,445.7708,446.61505,442.6757,453.86816,460.503,470.8903,489.0721,493.6743,486.91586,477.6071,472.9288,466.49863,465.63788,466.36716,465.50793,462.8761,456.7114,454.19553,452.18597,451.05115,447.73428,459.5585,483.58414,492.47556,489.61823,483.72574,481.23618,476.63834,472.664,467.27975,461.90073,459.37473,460.6832,462.8155,461.7852,460.04953,460.17786,465.5242,466.4003,464.08603,460.89798,456.06155,452.54733,451.1897,459.7673,463.4597,466.29724,464.79575,459.99686,459.61826,463.2981,462.1174,466.257,469.19772,473.76068,475.62994,475.4522,483.88434,484.94955,482.79883,487.68878,486.4308,480.9103,475.8806,474.74402,471.1078,474.23392,474.31073,471.54205,474.92197],"type":"scatter"}],                        {"template":{"data":{"b ...

# %%
import matplotlib.pyplot as plt

# Plot training & validation loss
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'], label='Training Loss', color='blue')
plt.plot(history.history.get('val_loss', []), label='Validation Loss', color='red')
plt.title('Model Loss During Training for ASIAN')
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.grid(True)
plt.show()

# %%
model_ohlcv.save("model_ohlcv_LSTM_ASIAN_Feb.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
