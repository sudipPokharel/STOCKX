# %%
import pandas as pd
import json
import os
import requests
from datetime import datetime, timezone
import matplotlib as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score
import numpy as np
import statsmodels.api as sms
from tensorflow.keras.layers import Dropout

# %%
url = "https://merolagani.com/handlers/TechnicalChartHandler.ashx?type=get_advanced_chart&symbol=AKJCL&resolution=1D&rangeStartDate=1642411546&rangeEndDate=1770545453&from=&isAdjust=1&currencyCode=NPR"
response = requests.get(url)
data = response.json()


with open("ANKHU_Feb.json", "w") as f:
    json.dump(data, f)

# %%
companies = ["/content/ANKHU_Feb.json"]

for symbol in companies:
    with open(f"{symbol}", 'r') as f:
        data = json.load(f)
        print(data)
    dates = [datetime.fromtimestamp(ts, tz=timezone.utc).strftime('%Y-%m-%d') for ts in data['t']]
    df=pd.DataFrame({
    "Date":dates,
    "Open":data['o'],
    "Close":data['c'],
    "High":data['h'],
    "Low":data['l'],
    "Volume":data['v']

})
    csv_filename = os.path.basename(symbol).replace('.json', '.csv')
    print(csv_filename)
    df.to_csv(csv_filename,index=False)
    print(f"{csv_filename}Feb_created")
# Out:
# {'t': [1642452300, 1642538700, 1642625100, 1642711500, 1642970700, 1643057100, 1643143500, 1643229900, 1643316300, 1643575500, 1643661900, 1643748300, 1643921100, 1644180300, 1644266700, 1644353100, 1644439500, 1644525900, 1644785100, 1644871500, 1644957900, 1645044300, 1645130700, 1645389900, 1645476300, 1645562700, 1645649100, 1645735500, 1645994700, 1646081100, 1646253900, 1646599500, 1646685900, 1646858700, 1646945100, 1647204300, 1647290700, 1647377100, 1647463500, 1647809100, 1647895500, 1647981900, 1648068300, 1648154700, 1648413900, 1648500300, 1648586700, 1648673100, 1648759500, 1649018700, 1649105100, 1649191500, 1649277900, 1649364300, 1649709900, 1649796300, 1649882700, 1650228300, 1650314700, 1650401100, 1650487500, 1650573900, 1650833100, 1650919500, 1651005900, 1651092300, 1651178700, 1651524300, 1651697100, 1651783500, 1652042700, 1652129100, 1652215500, 1652301900, 1652388300, 1652820300, 1652906700, 1652993100, 1653079500, 1653338700, 1653425100, 1653511500, 1653597900, 1653684300, 1653943500, 1654029900, 1654116300, 1654202700, 1654289100, 1654548300, 1654634700, 1654721100, 1654807500, 1654893900, 1655153100, 1655239500, 1655325900, 1655412300, 1655498700, 1655671500, 1655757900, 1655844300, 1655930700, 1656017100, 1656103500, 1656276300, 1656362700, 1656449100, 1656535500, 1656621900, 1656708300, 1656881100, 1656967500, 1657053900, 1657140300, 1657226700, 1657313100, 1657572300, 1657658700, 1657745100, 1657831500, 1657917900, 1658090700, 1658177100, 1658263500, 1658349900, 1658436300, 1658522700, 1658695500, 1658781900, 1658868300, 1658954700, 1659041100, 1659127500, 1659300300, 1659386700, 1659473100, 1659559500, 1659645900, 1659732300, 1659905100, 1659991500, 1660077900, 1660164300, 1660250700, 1660509900, 1660596300, 1660682700, 1660769100, 1660855500, 1661114700, 1661201100, 1661287500, 1661373900, 1661460300, 1661546700, 1661719500, 1661805900, 1661892300, 1661978700, 1662064380, 1662151500, 1662324300, 1662410700, 1662497100, 1662583500, 1662669900, 1662929100, 1663015500, 1663101900, 1663188300, 1663274700, 1663361100, 1663533900, 1663706700, 1663793100, 1663879500, 1664138700, 1664311500, 1664397900, 1664484300, 1665348300, 1665434700, 1665521100, 1665607500, 1665693900, 1665953100, 1666039500, 1666212300, 1666298700, 1666557900, 1667249100, 1667335500, 1667421900, 1667508300, 1667767500, 1667853900, 1667940300, 1668026700, 1668113100, 1668372300, 1668458700, 1668545100, 1668631500, 1668717900, 1669149900, 1669236300, 1669322700, 1669581900, 1669668300, 1669754700, 1669841100, 1669927500, 1670186700, 1670273100, 1670359500, 1670445900, 1670791500, 1670877900, 1670964300, 1671050700, 1671137100, 1671396300, 1671482700, 1671569100, 1671655500, 1671741900, 1672087500, 1672173900, 1672260300, 1672346700, 1672605900, 1672692300, 1672778700, 1672865100, 1672951500, 1673210700, 1673297100, 1673383500, 1673556300, 1673988300, 1674074700, 1674161100, 1674506700, 1674593100, 1674679500, 1674765900, 1675025100, 1675111500, 1675197900, 1675284300, 1675370700, 1675629900, 1675716300, 1675802700, 1675889100, 1675975500, 1676234700, 1676407500, 1676493900, 1676580300, 1676925900, 1677098700, 1677185100, 1677444300, 1677530700, 1677617100, 1677703500, 1677789900, 1678049100, 1678221900, 1678394700, 1678653900, 1678740300, 1678826700, 1678913100, 1678999500, 1679258700, 1679345100, 1679517900, 1679604300, 1679863500, 1679949900, 1680036300, 1680122700, 1680209100, 1680468300, 1680554700, 1680641100, 1680727500, 1680813900, 1681073100, 1681159500, 1681245900, 1681332300, 1681418700, 1681677900, 1681764300, 1681850700, 1681937100, 1682023500, 1682282700, 1682369100, 1682455500, 1682541900, 1682628300, 1682887500, 1683060300, 1683146700, 1683233100, 1683492300, 1683578700, 1683665100, 1683751500, 1683837900, 1684097100, 1684183500, 1684269900, 1684356300, 1684442700, 1684701900, 1684788300, 1684874700, 1684961100, 1685306700, 1685479500, 1685565900, 1685652300, 1685911500, 1685997900, 1686084300, 1686170700, 168625710 ...
# ANKHU_Feb.csv
# ANKHU_Feb.csvFeb_created

# %%
df = pd.read_csv("ANKHU_Feb.csv")
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index('Date')
print(len(df))
# Out:
# 942

# %%
df.head()
# Out:
#               Open   Close    High     Low    Volume
# Date
# 2022-01-17  197.08  194.08  197.08  192.00  162598.0
# 2022-01-18  194.00  189.64  195.20  187.20  204240.0
# 2022-01-19  190.80  187.60  192.00  186.00  144065.0
# 2022-01-20  187.60  192.60  192.80  185.08  139968.0
# 2022-01-23  195.20  192.00  196.00  190.00  150700.0

# %%
df.tail()
# Out:
#              Open  Close   High    Low     Volume
# Date
# 2026-02-02  319.9  326.9  338.0  319.9  1252669.0
# 2026-02-03  320.4  322.0  333.0  320.4  1258177.0
# 2026-02-04  317.0  354.2  354.2  317.0  2346577.0
# 2026-02-05  361.2  352.8  372.3  351.0  1125013.0
# 2026-02-08  357.0  363.0  376.0  351.0  1426865.0

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
results = seasonal_decompose(df['Close'], model='additive', period=30)
results.plot()

# %%
def plot_graph(figsize, df_to_plot, column_name):
    # df_to_plot is already assumed to have 'Date' as its index
    df_to_plot = df_to_plot.sort_index()

    plt.figure(figsize=figsize)
    plt.plot(df_to_plot.index, df_to_plot[column_name], label=column_name)
    plt.title(f"ASIAN LIFE {column_name} Over Time")
    plt.xlabel("Date")
    plt.ylabel(column_name)
    plt.legend()
    plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(df['Open'], label='Open Price')
plt.plot(df['Close'], label='Close Price')
plt.plot(df['High'], label='High Price')
plt.plot(df['Low'], label='Low Price')
plt.plot(df['Volume'], label='Volume')

# %%
df['MA_10'] = df['Close'].rolling(10).mean()
df['MA_20'] = df['Close'].rolling(20).mean()

# %%
print(df.isna().sum())
# Out:
# Open       0
# Close      0
# High       0
# Low        0
# Volume     0
# MA_10      9
# MA_20     19
# dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(df['Close'], label='Close Price')
plt.plot(df['MA_10'], label='MA 10')
plt.legend()
plt.title("Close Price vs 10-day Moving Average")
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['Close'], label='Close Price')
plt.plot(df['MA_20'], label='MA 20')
plt.legend()
plt.title("Close Price vs 20-day Moving Average")
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# %%
len(df)
# Out:
# 942

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 942 entries, 2022-01-17 to 2026-02-08
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    942 non-null    float64
#  1   Close   942 non-null    float64
#  2   High    942 non-null    float64
#  3   Low     942 non-null    float64
#  4   Volume  942 non-null    float64
#  5   MA_10   933 non-null    float64
#  6   MA_20   923 non-null    float64
# dtypes: float64(7)
# memory usage: 58.9 KB

# %%
def plot_graph(figsize, df_to_plot, column_name):

    plt.figure(figsize=figsize)
    plt.plot(df_to_plot.index, df_to_plot[column_name], label=column_name)
    plt.title(f"ANKHU {column_name} Over Time")
    plt.xlabel("Date")
    plt.ylabel(column_name)
    plt.legend()
    plt.show()

# %%
import matplotlib.pyplot as plt
plot_graph((10, 5), df, "Close")

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import random
import os
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping

# %%
seed = 42
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)
os.environ["PYTHONHASHSEED"] = str(seed)

# %%
df = df[['Open','High','Low','Close','Volume']].copy()
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)

# stabilize volume
df['Volume'] = np.log1p(df['Volume'])

# %%
features = df[['Open','High','Low','Close','Volume']].values

# %%
window = 90
split = int(len(features) * 0.8)

train_raw = features[:split]
test_raw  = features[split - window:]

# %%
scaler_X = MinMaxScaler()
train_scaled = scaler_X.fit_transform(train_raw)
test_scaled  = scaler_X.transform(test_raw)

scaler_y = MinMaxScaler()
scaler_y.fit(train_raw[:, 3].reshape(-1, 1))
# Out:
# MinMaxScaler()

# %%
def create_sequences(data, window):
    X, y = [], []
    for i in range(window, len(data)):
        X.append(data[i-window:i])
        y.append(data[i, 3])  # Close
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.float32).reshape(-1,1)

# %%
X_train, y_train = create_sequences(train_scaled, window)
X_test, y_test   = create_sequences(test_scaled, window)

# %%
model_ohlcv = Sequential([
LSTM(128, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.2),
    LSTM(64),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dense(1)
])

model_ohlcv.compile(optimizer=tf.keras.optimizers.Adam(0.001), loss='mse')
model_ohlcv.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# Model: "sequential_48"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_97 (LSTM)                  │ (None, 90, 128)        │        68,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_99 (Dropout)            │ (None, 90, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_98 (LSTM)                  │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_100 (Dropout)           │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_97 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_98 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 120,129 (469.25 KB)
#  Trainable params: 120,129 (469.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stop = EarlyStopping(patience=10, restore_best_weights=True)

history = model_ohlcv.fit(
  X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_test, y_test),
    verbose=1
)
# Out:
# Epoch 1/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0660 - val_loss: 0.0207
# Epoch 2/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0077 - val_loss: 0.0201
# Epoch 3/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0055 - val_loss: 0.0193
# Epoch 4/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0046 - val_loss: 0.0168
# Epoch 5/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0039 - val_loss: 0.0160
# Epoch 6/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0044 - val_loss: 0.0150
# Epoch 7/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0037 - val_loss: 0.0135
# Epoch 8/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0040 - val_loss: 0.0117
# Epoch 9/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0036 - val_loss: 0.0113
# Epoch 10/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0037 - val_loss: 0.0115
# Epoch 11/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0033 - val_loss: 0.0115
# Epoch 12/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0033 - val_loss: 0.0101
# Epoch 13/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0035 - val_loss: 0.0108
# Epoch 14/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0036 - val_loss: 0.0098
# Epoch 15/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0035 - val_loss: 0.0103
# Epoch 16/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0030 - val_loss: 0.0103
# Epoch 17/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0029 - val_loss: 0.0113
# Epoch 18/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0032 - val_loss: 0.0117
# Epoch 19/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0025 - val_loss: 0.0127
# Epoch 20/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0032 - val_loss: 0.0100
# Epoch 21/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0031 - val_loss: 0.0103
# Epoch 22/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0029 - val_loss: 0.0112
# Epoch 23/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0028 - val_loss: 0.0103
# Epoch 24/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0027 - val_loss: 0.0090
# Epoch 25/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0026 - val_loss: 0.0084
# Epoch 26/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0026 - val_loss: 0.0085
# Epoch 27/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0026 - val_loss: 0.0094
# Epoch 28/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0027 - val_loss: 0.0103
# Epoch 29/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0024 - val_loss: 0.0086
# Epoch 30/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0025 - val_loss: 0.0073
# Epoch 31/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0023 - val_loss: 0.0074
# Epoch 32/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0019 - val_loss: 0.0061
# Epoch 33/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0023 - val_loss: 0.0068
# Epoch 34/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0021 - val_loss: 0.0066
# Epoch 35/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0023 - val_loss: 0.0057
# Epoch 36/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0022 - val_loss: 0.0072
# Epoch 37/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0021 - val_loss: 0.0063
# Epoch 38/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0021 - val_loss: 0.0070
# Epoch 39/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0021 - val_loss: 0.0076
# Epoch 40/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0019 - val_loss: 0.0082
# Epoch 41/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0017 - val_loss: 0.0066
# Epoch 42/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0018 - val_loss: 0.0061
# Epoch 43/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0016 - val_loss: 0.0070
# Epoch 44/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0016 - val_loss: 0.0054
# Epoch 45/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0016 - val_loss: 0.0067
# Epoch 46/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0020 - val_loss: 0.0078
# Epoch 47/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0016 - val_loss: 0.0079
# Epoch 48/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0015 - val_loss: 0.0059
# Epoch 49/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0018 - val_loss: 0.0052
# Epoch 50/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0015 - val_loss: 0.0056
# Epoch 51/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0015 - val_loss: 0.0056
# Epoch 52/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0015 - val_loss: 0.0061
# Epoch 53/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0014 - val_loss: 0.0070
# Epoch 54/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0016 - val_loss: 0.0055
# Epoch 55/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0016 - val_loss: 0.0054
# Epoch 56/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0015 - val_loss: 0.0055
# Epoch 57/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0014 - val_loss: 0.0051
# Epoch 58/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0014 - val_loss: 0.0053
# Epoch 59/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0015 - val_loss: 0.0059
# Epoch 60/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0013 - val_loss: 0.0054
# Epoch 61/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0016 - val_loss: 0.0069
# Epoch 62/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0014 - val_loss: 0.0056
# Epoch 63/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0016 - val_loss: 0.0058
# Epoch 64/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0015 - val_loss: 0.0082
# Epoch 65/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0016 - val_loss: 0.0074
# Epoch 66/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0015 - val_loss: 0.0070
# Epoch 67/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0013 - val_loss: 0.0060
# Epoch 68/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0014 - val_loss: 0.0066
# Epoch 69/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0013 - val_loss: 0.0066
# Epoch 70/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0014 - val_loss: 0.0077
# Epoch 71/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0015 - val_loss: 0.0076
# Epoch 72/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0013 - val_loss: 0.0061
# Epoch 73/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0011 - val_loss: 0.0059
# Epoch 74/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0012 - val_loss: 0.0065
# Epoch 75/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0014 - val_loss: 0.0053
# Epoch 76/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0013 - val_loss: 0.0074
# Epoch 77/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0013 - val_loss: 0.0056
# Epoch 78/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0013 - val_loss: 0.0072
# Epoch 79/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0013 - val_loss: 0.0063
# Epoch 80/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0013 - val_loss: 0.0053
# Epoch 81/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0013 - val_loss: 0.0062
# Epoch 82/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0012 - val_loss: 0.0068
# Epoch 83/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0014 - val_loss: 0.0074
# Epoch 84/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0013 - val_loss: 0.0086
# Epoch 85/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0013 - val_loss: 0.0064
# Epoch 86/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0012 - val_loss: 0.0062
# Epoch 87/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0012 - val_loss: 0.0063
# Epoch 88/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0012 - val_loss: 0.0062
# Epoch 89/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0012 - val_loss: 0.0084
# Epoch 90/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0014 - val_loss: 0.0061
# Epoch 91/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0012 - val_loss: 0.0046
# Epoch 92/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0012 - val_loss: 0.0056
# Epoch 93/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0010 - val_loss: 0.0065
# Epoch 94/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0011 - val_loss: 0.0069
# Epoch 95/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0014 - val_loss: 0.0077
# Epoch 96/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0015 - val_loss: 0.0061
# Epoch 97/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0012 - val_loss: 0.0066
# Epoch 98/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0012 - val_loss: 0.0063
# Epoch 99/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0012 - val_loss: 0.0064
# Epoch 100/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0013 - val_loss: 0.0044

# %%
pred_scaled = model_ohlcv.predict(X_test)

if pred_scaled.ndim == 3:
    pred_scaled = pred_scaled[:, -1, :]

pred = scaler_y.inverse_transform(pred_scaled)
actual = scaler_y.inverse_transform(y_test)

rmse = np.sqrt(mean_squared_error(actual, pred))
mae = mean_absolute_error(actual, pred)

print("RMSE for ANKHU:", rmse)
print("MAE for  ANKHU:", mae)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# RMSE for ANKHU: 10.019137190715911
# MAE for  ANKHU: 4.80246114730835

# %%
import plotly.graph_objects as go
import numpy as np

actual_flat = actual.flatten()
pred_flat = pred.flatten()

fig = go.Figure()

fig.add_trace(
    go.Scatter(
        y=actual_flat,
        mode="lines",
        name="Actual",
        line=dict(width=2)
    )
)

fig.add_trace(
    go.Scatter(
        y=pred_flat,
        mode="lines",
        name="Predicted",
        line=dict(
            width=2,
            shape="spline"
        )
    )
)

fig.update_layout(
    title="LSTM with OHLCV — Actual vs Predicted For ANKHU",
    xaxis_title="Time",
    yaxis_title="Price",
    hovermode="x unified",
    template="plotly_white"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="68119548-5f31-4310-9607-a168ac4b1ee1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("68119548-5f31-4310-9607-a168ac4b1ee1")) {                    Plotly.newPlot(                        "68119548-5f31-4310-9607-a168ac4b1ee1",                        [{"line":{"width":2},"mode":"lines","name":"Actual","y":[202.23001,201.84001,201.78,199.83,203.37001,207.68,209.87,206.12001,210.74,207.39001,204.02,204.27,205.67,206.88,206.05,210.21,211.08002,207.86,209.92,215.95,219.19,213.63,209.86002,206.59,205.45001,205.35,205.35,206.78001,211.63,207.94,206.15,207.47002,207.15001,206.6,208.23001,207.59999,205.97002,205.34,205.65001,205.05,207.43001,209.24,209.70001,208.20001,213.55002,211.96,209.72,211.23001,218.06,211.13,209.88,211.26,210.97,210.93,209.82,210.61,211.53,210.63,209.44,208.24,205.99,207.91,208.34,206.84,208.09,207.12,208.52,208.20001,216.61,214.16002,215.16,218.31,224.8,229.0,222.15,224.48001,222.78001,217.82,215.36,211.92001,215.09001,211.3,209.65001,211.89001,209.03,207.75002,206.6,207.2,206.25,206.22002,206.37001,205.12999,205.11,203.78001,204.01001,203.69,207.85,204.08,201.46,202.91,200.42001,199.01,197.11,196.04001,191.33,173.0,190.3,199.90001,195.3,195.0,196.5,192.9,189.0,192.5,187.0,190.0,187.20001,184.90001,183.40001,184.0,183.1,193.8,191.0,194.0,198.7,195.20001,190.20001,192.0,190.40001,187.0,186.20001,186.3,186.0,186.8,185.5,186.0,188.1,187.09999,186.9,192.9,194.1,193.40001,191.0,192.0,190.20001,190.0,188.3,187.5,186.9,186.0,185.79999,184.5,184.40001,183.0,183.0,184.0,183.20001,182.4,186.9,184.0,183.0,182.7,186.7,186.9,192.4,193.0,190.8,192.6,197.0,198.2,205.9,200.0,201.9,202.8,209.09999,226.1,232.1,244.0,268.4,282.2,277.0,304.7,312.0,326.4,326.9,322.0,354.2,352.8,363.0],"type":"scatter"},{"line":{"shape":"spline","width":2},"mode":"lines","name":"Predicted","y":[201.79056,201.13162,201.01129,201.75172,200.87361,202.8162,206.78355,209.10634,207.4755,210.3328,208.50111,205.50839,204.40309,206.31602,209.97705,206.79858,209.70447,211.76361,208.99812,209.19455,215.524,218.02478,214.55945,210.35625,207.63898,205.3319,205.7611,206.54622,205.96257,209.78218,211.5785,206.57922,204.69748,207.45389,205.91913,206.67363,207.93564,206.39532,205.5928,204.89432,205.48077,206.2822,208.9242,208.43813,209.06816,211.59122,212.817,209.19876,210.5435,218.09697,213.70493,209.10265,211.3955,211.03065,211.81042,209.31975,209.81079,210.64487,211.17793,209.08374,207.63606,206.36505,206.28154,207.62506,208.35461,209.16093,207.31076,206.70876,208.09029,214.51266,215.70267,213.11922,215.71758,222.18146,225.64032,223.30806,220.10825,220.723,218.04501,214.37561,211.16304,212.38515,212.71701,211.05948,210.68417,209.93918,207.50148,206.00653,206.65662,205.91115,205.61919,205.51083,204.99728,204.2177,203.88065,203.80197,203.32494,206.0563,206.10641,202.93044,201.51877,202.06277,201.05229,199.27997,197.30762,195.90564,184.72964,188.28908,198.24182,199.64087,197.6995,196.58047,196.36224,192.94026,194.65157,190.24277,190.01747,189.84616,188.4439,186.94362,186.44661,185.44011,191.71036,194.5503,195.1081,197.76303,197.62537,194.5029,192.36472,192.66785,190.89453,189.51611,189.20164,189.21399,189.47266,189.1236,188.66776,190.06316,190.48404,190.27805,193.0069,194.49107,194.97961,193.60117,193.68222,193.5105,192.04636,190.66525,190.79079,189.52498,188.44177,188.1827,187.89279,187.33804,186.52573,185.56084,186.66443,186.3989,185.0696,187.14539,186.99353,185.5807,185.16374,187.2103,189.67458,192.88708,194.09807,193.2543,193.29433,197.71437,199.93257,205.59444,203.89897,201.87079,202.2394,208.47583,224.14621,234.45863,238.37996,259.64096,276.32925,269.52527,280.01675,290.28217,299.61218,292.0391,285.82153,309.77454,310.18005],"type":"scatter"}],          ...

# %%
import matplotlib.pyplot as plt

# Plot training & validation loss
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'], label='Training Loss', color='blue')
plt.plot(history.history.get('val_loss', []), label='Validation Loss', color='red')
plt.title('Model Loss During Training for ANKHU')
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.grid(True)
plt.show()

# %%
model_ohlcv.save("model_ohlcv_LSTM_ANKHU_Feb.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
