# %%
import pandas as pd
import json
import os
import requests
from datetime import datetime, timezone
import matplotlib as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score
import numpy as np
import statsmodels.api as sms
from tensorflow.keras.layers import Dropout

# %%
url = "https://merolagani.com/handlers/TechnicalChartHandler.ashx?type=get_advanced_chart&symbol=SAHAS&resolution=1D&rangeStartDate=1642411546&rangeEndDate=1770545453&from=&isAdjust=1&currencyCode=NPR"
response = requests.get(url)
data = response.json()


with open("SAHAS_Feb.json", "w") as f:
    json.dump(data, f)

# %%
companies = ["/content/SAHAS_Feb.json"]

for symbol in companies:
    with open(f"{symbol}", 'r') as f:
        data = json.load(f)
        print(data)
    dates = [datetime.fromtimestamp(ts, tz=timezone.utc).strftime('%Y-%m-%d') for ts in data['t']]
    df=pd.DataFrame({
    "Date":dates,
    "Open":data['o'],
    "Close":data['c'],
    "High":data['h'],
    "Low":data['l'],
    "Volume":data['v']

})
    csv_filename = os.path.basename(symbol).replace('.json', '.csv')
    print(csv_filename)
    df.to_csv(csv_filename,index=False)
    print(f"{csv_filename}Feb_created")
# Out:
# {'t': [1642452300, 1642538700, 1642625100, 1642711500, 1642970700, 1643057100, 1643143500, 1643229900, 1643316300, 1643575500, 1643661900, 1643748300, 1643921100, 1644180300, 1644266700, 1644353100, 1644439500, 1644525900, 1644785100, 1644871500, 1644957900, 1645044300, 1645130700, 1645389900, 1645476300, 1645562700, 1645649100, 1645735500, 1645994700, 1646081100, 1646253900, 1646599500, 1646685900, 1646858700, 1646945100, 1647204300, 1647290700, 1647377100, 1647463500, 1647809100, 1647895500, 1647981900, 1648068300, 1648154700, 1648413900, 1648500300, 1648586700, 1648673100, 1648759500, 1649018700, 1649105100, 1649191500, 1649277900, 1649364300, 1649709900, 1649796300, 1649882700, 1650228300, 1650314700, 1650401100, 1650487500, 1650573900, 1650833100, 1650919500, 1651005900, 1651092300, 1651178700, 1651524300, 1651697100, 1651783500, 1652042700, 1652129100, 1652215500, 1652301900, 1652388300, 1652820300, 1652906700, 1652993100, 1653079500, 1653338700, 1653425100, 1653511500, 1653597900, 1653684300, 1653943500, 1654029900, 1654116300, 1654202700, 1654289100, 1654548300, 1654634700, 1654721100, 1654807500, 1654893900, 1655153100, 1655239500, 1655325900, 1655412300, 1655498700, 1655671500, 1655757900, 1655844300, 1655930700, 1656017100, 1656103500, 1656276300, 1656362700, 1656449100, 1656535500, 1656621900, 1656708300, 1656881100, 1656967500, 1657053900, 1657140300, 1657226700, 1657313100, 1657572300, 1657658700, 1657745100, 1657831500, 1657917900, 1658090700, 1658177100, 1658263500, 1658349900, 1658436300, 1658522700, 1658695500, 1658781900, 1658868300, 1658954700, 1659041100, 1659127500, 1659300300, 1659386700, 1659473100, 1659559500, 1659645900, 1659732300, 1659905100, 1659991500, 1660077900, 1660164300, 1660250700, 1660509900, 1660596300, 1660682700, 1660769100, 1660855500, 1661114700, 1661201100, 1661287500, 1661373900, 1661460300, 1661546700, 1661719500, 1661805900, 1661892300, 1661978700, 1662064380, 1662151500, 1662324300, 1662410700, 1662497100, 1662583500, 1662669900, 1662929100, 1663015500, 1663101900, 1663188300, 1663274700, 1663361100, 1663533900, 1663706700, 1663793100, 1663879500, 1664138700, 1664311500, 1664397900, 1664484300, 1665348300, 1665434700, 1665521100, 1665607500, 1665693900, 1665953100, 1666039500, 1666212300, 1666298700, 1666557900, 1667249100, 1667335500, 1667421900, 1667508300, 1667767500, 1667853900, 1667940300, 1668026700, 1668113100, 1668372300, 1668458700, 1668545100, 1668631500, 1668717900, 1669149900, 1669236300, 1669322700, 1669581900, 1669668300, 1669754700, 1669841100, 1669927500, 1670186700, 1670273100, 1670359500, 1670445900, 1670791500, 1670877900, 1670964300, 1671050700, 1671137100, 1671396300, 1671482700, 1671569100, 1671655500, 1671741900, 1672087500, 1672173900, 1672260300, 1672346700, 1672605900, 1672692300, 1672778700, 1672865100, 1672951500, 1673210700, 1673297100, 1673383500, 1673556300, 1673988300, 1674074700, 1674161100, 1674506700, 1674593100, 1674679500, 1674765900, 1675025100, 1675111500, 1675197900, 1675284300, 1675370700, 1675629900, 1675716300, 1675802700, 1675889100, 1675975500, 1676234700, 1676407500, 1676493900, 1676580300, 1676925900, 1677098700, 1677185100, 1677444300, 1677530700, 1677617100, 1677703500, 1677789900, 1678049100, 1678221900, 1678394700, 1678653900, 1678740300, 1678826700, 1678913100, 1678999500, 1679258700, 1679345100, 1679517900, 1679604300, 1679863500, 1679949900, 1680036300, 1680122700, 1680209100, 1680468300, 1680554700, 1680641100, 1680727500, 1680813900, 1681073100, 1681159500, 1681245900, 1681332300, 1681418700, 1681677900, 1681764300, 1681850700, 1681937100, 1682023500, 1682282700, 1682369100, 1682455500, 1682541900, 1682628300, 1682887500, 1683060300, 1683146700, 1683233100, 1683492300, 1683578700, 1683665100, 1683751500, 1683837900, 1684097100, 1684183500, 1684269900, 1684356300, 1684442700, 1684701900, 1684788300, 1684874700, 1684961100, 1685306700, 1685479500, 1685565900, 1685652300, 1685911500, 1685997900, 1686084300, 1686170700, 168625710 ...
# SAHAS_Feb.csv
# SAHAS_Feb.csvFeb_created

# %%
df = pd.read_csv("SAHAS_Feb.csv")
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index('Date')
print(len(df))
# Out:
# 942

# %%
df.head()
# Out:
#               Open   Close    High     Low   Volume
# Date
# 2022-01-17  495.87  498.17  505.05  487.45  50062.0
# 2022-01-18  497.40  493.57  507.35  486.69  39260.0
# 2022-01-19  485.92  478.26  497.40  475.36  39319.0
# 2022-01-20  470.69  484.01  486.69  470.69  44219.0
# 2022-01-23  489.74  477.50  497.40  477.50  28508.0

# %%
df.tail()
# Out:
#              Open  Close   High    Low   Volume
# Date
# 2026-02-02  560.0  562.5  590.0  560.0  87207.0
# 2026-02-03  557.8  558.9  567.0  555.0  65600.0
# 2026-02-04  552.0  557.6  564.0  552.0  50982.0
# 2026-02-05  547.7  563.0  563.9  547.7  70559.0
# 2026-02-08  557.1  564.9  568.0  557.1  64425.0

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
results = seasonal_decompose(df['Close'], model='additive', period=30)
results.plot()

# %%
def plot_graph(figsize, df_to_plot, column_name):
    # df_to_plot is already assumed to have 'Date' as its index
    df_to_plot = df_to_plot.sort_index()

    plt.figure(figsize=figsize)
    plt.plot(df_to_plot.index, df_to_plot[column_name], label=column_name)
    plt.title(f"SAHAS {column_name} Over Time")
    plt.xlabel("Date")
    plt.ylabel(column_name)
    plt.legend()
    plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(df['Open'], label='Open Price')
plt.plot(df['Close'], label='Close Price')
plt.plot(df['High'], label='High Price')
plt.plot(df['Low'], label='Low Price')
plt.plot(df['Volume'], label='Volume')

# %%
df['MA_10'] = df['Close'].rolling(10).mean()
df['MA_20'] = df['Close'].rolling(20).mean()

# %%
print(df.isna().sum())
# Out:
# Open       0
# Close      0
# High       0
# Low        0
# Volume     0
# MA_10      9
# MA_20     19
# dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(df['Close'], label='Close Price')
plt.plot(df['MA_10'], label='MA 10')
plt.legend()
plt.title("Close Price vs 10-day Moving Average")
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['Close'], label='Close Price')
plt.plot(df['MA_20'], label='MA 20')
plt.legend()
plt.title("Close Price vs 20-day Moving Average")
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# %%
len(df)
# Out:
# 942

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 942 entries, 2022-01-17 to 2026-02-08
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    942 non-null    float64
#  1   Close   942 non-null    float64
#  2   High    942 non-null    float64
#  3   Low     942 non-null    float64
#  4   Volume  942 non-null    float64
#  5   MA_10   933 non-null    float64
#  6   MA_20   923 non-null    float64
# dtypes: float64(7)
# memory usage: 58.9 KB

# %%
def plot_graph(figsize, df_to_plot, column_name):

    plt.figure(figsize=figsize)
    plt.plot(df_to_plot.index, df_to_plot[column_name], label=column_name)
    plt.title(f"SAHAS {column_name} Over Time")
    plt.xlabel("Date")
    plt.ylabel(column_name)
    plt.legend()
    plt.show()

# %%
import matplotlib.pyplot as plt
plot_graph((10, 5), df, "Close")

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import random
import os
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping

# %%
seed = 42
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)
os.environ["PYTHONHASHSEED"] = str(seed)

# %%
df = df[['Open','High','Low','Close','Volume']].copy()
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)

# stabilize volume
df['Volume'] = np.log1p(df['Volume'])

# %%
features = df[['Open','High','Low','Close','Volume']].values

# %%
window = 60
split = int(len(features) * 0.8)

train_raw = features[:split]
test_raw  = features[split - window:]

# %%
scaler_X = MinMaxScaler()
train_scaled = scaler_X.fit_transform(train_raw)
test_scaled  = scaler_X.transform(test_raw)

scaler_y = MinMaxScaler()
scaler_y.fit(train_raw[:, 3].reshape(-1, 1))
# Out:
# MinMaxScaler()

# %%
def create_sequences(data, window):
    X, y = [], []
    for i in range(window, len(data)):
        X.append(data[i-window:i])
        y.append(data[i, 3])  # Close
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.float32).reshape(-1,1)

# %%
X_train, y_train = create_sequences(train_scaled, window)
X_test, y_test   = create_sequences(test_scaled, window)

# %%
model_ohlcv = Sequential([
    LSTM(256, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])), # Increased LSTM units
    Dropout(0.3), # Adjusted dropout rate
    LSTM(128, return_sequences=False), # Increased LSTM units
    Dropout(0.2), # Adjusted dropout rate
    Dense(64, activation='relu'), # Adjusted Dense units
    Dense(1)
])

model_ohlcv.compile(optimizer=tf.keras.optimizers.Adam(0.001), loss='mse')
model_ohlcv.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# Model: "sequential_22"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_44 (LSTM)                  │ (None, 60, 256)        │       268,288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_44 (Dropout)            │ (None, 60, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_45 (LSTM)                  │ (None, 128)            │       197,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_45 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_44 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_45 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 473,729 (1.81 MB)
#  Trainable params: 473,729 (1.81 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stop = EarlyStopping(patience=10, restore_best_weights=True)

history = model_ohlcv.fit(
  X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_test, y_test),
    verbose=1
)
# Out:
# Epoch 1/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.0387 - val_loss: 0.0343
# Epoch 2/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0066 - val_loss: 0.0266
# Epoch 3/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0056 - val_loss: 0.0156
# Epoch 4/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0051 - val_loss: 0.0137
# Epoch 5/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0045 - val_loss: 0.0124
# Epoch 6/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0051 - val_loss: 0.0092
# Epoch 7/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0046 - val_loss: 0.0071
# Epoch 8/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0043 - val_loss: 0.0081
# Epoch 9/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0041 - val_loss: 0.0093
# Epoch 10/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 11/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0042 - val_loss: 0.0049
# Epoch 12/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0036 - val_loss: 0.0099
# Epoch 13/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0035 - val_loss: 0.0042
# Epoch 14/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0037 - val_loss: 0.0025
# Epoch 15/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0038 - val_loss: 0.0098
# Epoch 16/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 17/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 18/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0031 - val_loss: 0.0072
# Epoch 19/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0033 - val_loss: 0.0055
# Epoch 20/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0029 - val_loss: 0.0050
# Epoch 21/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0028 - val_loss: 0.0047
# Epoch 22/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0026 - val_loss: 0.0036
# Epoch 23/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0031 - val_loss: 0.0023
# Epoch 24/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0026 - val_loss: 0.0020
# Epoch 25/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0026 - val_loss: 0.0031
# Epoch 26/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0025 - val_loss: 0.0047
# Epoch 27/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0026 - val_loss: 0.0031
# Epoch 28/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0026 - val_loss: 0.0039
# Epoch 29/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0026 - val_loss: 0.0036
# Epoch 30/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0028 - val_loss: 0.0038
# Epoch 31/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0023 - val_loss: 0.0027
# Epoch 32/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0024 - val_loss: 0.0029
# Epoch 33/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0027 - val_loss: 0.0019
# Epoch 34/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0025 - val_loss: 0.0029
# Epoch 35/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 36/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0024 - val_loss: 0.0030
# Epoch 37/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0023 - val_loss: 0.0031
# Epoch 38/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0025 - val_loss: 0.0027
# Epoch 39/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0022 - val_loss: 0.0033
# Epoch 40/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 41/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0023 - val_loss: 0.0063
# Epoch 42/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 43/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0021 - val_loss: 0.0058
# Epoch 44/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0022 - val_loss: 0.0035
# Epoch 45/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0022 - val_loss: 0.0047
# Epoch 46/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0023 - val_loss: 0.0038
# Epoch 47/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0020 - val_loss: 0.0026
# Epoch 48/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0019 - val_loss: 0.0039
# Epoch 49/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0020 - val_loss: 0.0057
# Epoch 50/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0021 - val_loss: 0.0029
# Epoch 51/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0019 - val_loss: 0.0045
# Epoch 52/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0020 - val_loss: 0.0060
# Epoch 53/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0023 - val_loss: 0.0074
# Epoch 54/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0018 - val_loss: 0.0048
# Epoch 55/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0020 - val_loss: 0.0024
# Epoch 56/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0021 - val_loss: 0.0042
# Epoch 57/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0018 - val_loss: 0.0050
# Epoch 58/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0017 - val_loss: 0.0056
# Epoch 59/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0021 - val_loss: 0.0066
# Epoch 60/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 61/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0019 - val_loss: 0.0061
# Epoch 62/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0020 - val_loss: 0.0053
# Epoch 63/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0018 - val_loss: 0.0049
# Epoch 64/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0018 - val_loss: 0.0041
# Epoch 65/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0018 - val_loss: 0.0048
# Epoch 66/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0020 - val_loss: 0.0027
# Epoch 67/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0018 - val_loss: 0.0057
# Epoch 68/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0019 - val_loss: 0.0054
# Epoch 69/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 70/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0019 - val_loss: 0.0065
# Epoch 71/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0017 - val_loss: 0.0033
# Epoch 72/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0017 - val_loss: 0.0051
# Epoch 73/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0018 - val_loss: 0.0048
# Epoch 74/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0016 - val_loss: 0.0030
# Epoch 75/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0018 - val_loss: 0.0055
# Epoch 76/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0021 - val_loss: 0.0052
# Epoch 77/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0019 - val_loss: 0.0035
# Epoch 78/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0017 - val_loss: 0.0043
# Epoch 79/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0016 - val_loss: 0.0033
# Epoch 80/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 81/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - val_loss: 0.0041
# Epoch 82/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0018 - val_loss: 0.0044
# Epoch 83/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0017 - val_loss: 0.0060
# Epoch 84/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0017 - val_loss: 0.0053
# Epoch 85/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0018 - val_loss: 0.0053
# Epoch 86/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0018 - val_loss: 0.0065
# Epoch 87/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0018 - val_loss: 0.0052
# Epoch 88/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0017 - val_loss: 0.0046
# Epoch 89/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0017 - val_loss: 0.0068
# Epoch 90/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0021 - val_loss: 0.0046
# Epoch 91/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 92/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0018 - val_loss: 0.0035
# Epoch 93/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 94/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 95/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0016 - val_loss: 0.0031
# Epoch 96/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 97/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0018 - val_loss: 0.0042
# Epoch 98/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 99/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 100/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0017 - val_loss: 0.0019

# %%
pred_scaled = model_ohlcv.predict(X_test)

if pred_scaled.ndim == 3:
    pred_scaled = pred_scaled[:, -1, :]

pred = scaler_y.inverse_transform(pred_scaled)
actual = scaler_y.inverse_transform(y_test)

rmse = np.sqrt(mean_squared_error(actual, pred))
mae = mean_absolute_error(actual, pred)

print("RMSE for SAHAS:", rmse)
print("MAE for  SAHAS:", mae)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# RMSE for SAHAS: 10.78344456547987
# MAE for  SAHAS: 8.186869621276855

# %%
import plotly.graph_objects as go
import numpy as np

actual_flat = actual.flatten()
pred_flat = pred.flatten()

fig = go.Figure()

fig.add_trace(
    go.Scatter(
        y=actual_flat,
        mode="lines",
        name="Actual",
        line=dict(width=2)
    )
)

fig.add_trace(
    go.Scatter(
        y=pred_flat,
        mode="lines",
        name="Predicted",
        line=dict(
            width=2,
            shape="spline"
        )
    )
)

fig.update_layout(
    title="LSTM with OHLCV — Actual vs Predicted For SAHAS",
    xaxis_title="Time",
    yaxis_title="Price",
    hovermode="x unified",
    template="plotly_white"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2feb5572-d5d0-4b22-a727-ba3feb7c66c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2feb5572-d5d0-4b22-a727-ba3feb7c66c1")) {                    Plotly.newPlot(                        "2feb5572-d5d0-4b22-a727-ba3feb7c66c1",                        [{"line":{"width":2},"mode":"lines","name":"Actual","y":[411.69,412.27002,412.85,414.30002,414.68002,417.23,425.19,420.93,420.19,419.56003,414.5,412.84,411.64,411.82,411.86002,414.36002,416.22,416.24,441.63,443.14,441.03998,429.0,430.38,423.42,424.39,427.03,427.03,432.35,440.49,435.15002,432.14,431.57,430.35,426.99,429.68,428.2,429.07,428.09,429.0,433.93002,440.78,442.79,464.82,459.92,468.82,458.89,456.2,458.03,450.73,444.38998,450.85,456.32,456.63998,466.97998,491.79,486.73,486.69,509.09,504.96,489.73,483.8,496.73,496.13998,490.92,489.38,498.6,511.59003,528.95996,549.81,547.37,564.79,570.68,563.64,565.29,561.95,556.39,556.41,552.93,554.91003,553.17,559.39,552.9,552.69,558.81,563.06,553.66,543.67,530.43,525.78,531.06,534.74,529.41,529.07,528.63995,529.21,534.58,545.9,536.72003,529.89,533.02,533.4,529.05,527.19,522.32,513.03,487.6,519.03,533.97003,528.93,530.17,542.98004,525.62,512.48004,517.44,505.78998,511.57004,504.21002,504.13,508.18,517.77,513.06,534.71,540.5,557.52,555.45,549.59,543.06006,552.07,549.42004,545.45,542.56,556.12,548.93,551.24,551.24,561.32,571.07,561.98004,555.37,562.1,576.9,570.0,565.69995,565.5,555.9,559.0,555.0,549.0,543.0,543.8,545.0,540.0,539.2,538.0,538.8,543.0,546.0,544.0,549.10004,543.8,541.5,543.0,553.60004,551.0,552.0,548.0,544.89996,543.0,550.5,548.0,544.0,548.0,549.0,547.9,551.0,560.0,560.0,565.8,579.9,574.9,565.0,568.39996,564.9,562.0,562.5,558.89996,557.6,563.0,564.9],"type":"scatter"},{"line":{"shape":"spline","width":2},"mode":"lines","name":"Predicted","y":[412.1624,409.1211,410.35007,412.20206,413.8901,413.73746,416.13617,424.38492,419.95822,420.75305,419.4301,416.66885,413.9798,415.05304,413.6034,413.40253,416.26773,419.88312,417.0739,440.67847,439.55862,439.43707,430.99274,430.9424,422.86478,424.17386,427.13635,427.4232,431.12576,439.01065,438.4653,434.70886,430.69852,431.0092,428.69516,429.71106,429.93768,428.2599,426.29752,428.73367,432.55365,438.36752,440.77884,459.60513,455.8599,463.99173,456.25882,453.09772,455.25098,452.55273,444.7103,448.99738,454.02066,454.7102,466.3513,486.5851,480.26117,483.3223,503.63257,496.18997,489.95578,482.10776,491.47958,491.1696,487.44284,490.36694,493.67313,505.2623,520.3755,538.67285,536.8849,555.0707,556.23706,554.1235,557.8159,554.9641,549.9538,553.21173,547.68506,551.18024,546.3371,552.75903,547.6139,547.9979,551.17163,557.70825,544.90454,539.78845,527.7889,523.0592,523.6827,526.17737,521.93866,522.7571,521.63434,522.2431,523.9782,535.0992,526.76715,523.7584,523.4627,524.11993,521.42834,518.56415,514.96857,509.26712,483.86554,513.88446,514.946,517.4972,520.9995,532.3139,519.386,510.993,517.3883,500.55658,507.99887,498.12222,499.63806,501.47064,510.95065,505.05475,528.5909,527.28033,545.12506,540.71265,540.3665,535.7053,540.5506,539.9613,537.7434,537.1041,552.5957,537.1275,547.0278,542.17944,554.9584,557.732,555.1057,549.93225,553.1065,564.28033,556.83405,557.8004,556.323,550.4885,551.9902,547.42584,544.18243,537.80664,536.67816,538.72656,533.0486,533.895,530.29834,529.46643,533.5504,535.5792,535.3078,538.6077,532.7391,532.42004,534.0141,542.11053,541.0498,542.8896,537.781,537.87683,536.0012,541.0821,535.85156,537.2982,539.5278,540.16486,540.093,542.07404,551.3028,549.18054,555.6326,567.38245,561.8586,558.90326,558.3216,555.84174,554.32465,561.70483,548.18976,552.3819,552.2295],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5 ...

# %%
import matplotlib.pyplot as plt

# Plot training & validation loss
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'], label='Training Loss', color='blue')
plt.plot(history.history.get('val_loss', []), label='Validation Loss', color='red')
plt.title('Model Loss During Training for ANKHU')
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.grid(True)
plt.show()

# %%
model_ohlcv.save("model_ohlcv_LSTM_SAHAS_Feb.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
