# %%
import pandas as pd
import json
import os
import requests
from datetime import datetime, timezone
import matplotlib as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score
import numpy as np
import statsmodels.api as sms
from tensorflow.keras.layers import Dropout
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 7
#       5 from datetime import datetime, timezone
#       6 import matplotlib as plt
# ----> 7 from sklearn.preprocessing import MinMaxScaler
#       8 from sklearn.model_selection import train_test_split
#       9 from sklearn.metrics import mean_squared_error,r2_score
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
url = "https://merolagani.com/handlers/TechnicalChartHandler.ashx?type=get_advanced_chart&symbol=SBL&resolution=1D&rangeStartDate=1642411546&rangeEndDate=1768820807&from=&isAdjust=1&currencyCode=NPR"
response = requests.get(url)
data = response.json()


with open("slb.json", "w") as f:
    json.dump(data, f)

# %%
companies = ["/content/slb.json"]

for symbol in companies:
    with open(f"{symbol}", 'r') as f:
        data = json.load(f)
        print(data)
    dates = [datetime.fromtimestamp(ts, tz=timezone.utc).strftime('%Y-%m-%d') for ts in data['t']]
    df=pd.DataFrame({
    "Date":dates,
    "Open":data['o'],
    "Close":data['c'],
    "High":data['h'],
    "Low":data['l'],
    "Volume":data['v']

})
    csv_filename = os.path.basename(symbol).replace('.json', '.csv')
    print(csv_filename)
    df.to_csv(csv_filename,index=False)
    print(f"{csv_filename}created")
# Out:
# {'t': [1642452300, 1642538700, 1642625100, 1642711500, 1642970700, 1643057100, 1643143500, 1643229900, 1643316300, 1643575500, 1643661900, 1643748300, 1643921100, 1644180300, 1644266700, 1644353100, 1644439500, 1644525900, 1644785100, 1644871500, 1644957900, 1645044300, 1645130700, 1645389900, 1645476300, 1645562700, 1645649100, 1645735500, 1645994700, 1646081100, 1646253900, 1646599500, 1646685900, 1646858700, 1646945100, 1647204300, 1647290700, 1647377100, 1647463500, 1647809100, 1647895500, 1647981900, 1648068300, 1648154700, 1648413900, 1648500300, 1648586700, 1648673100, 1648759500, 1649018700, 1649105100, 1649191500, 1649277900, 1649364300, 1649709900, 1649796300, 1649882700, 1650228300, 1650314700, 1650401100, 1650487500, 1650573900, 1650833100, 1650919500, 1651005900, 1651092300, 1651178700, 1651524300, 1651697100, 1651783500, 1652042700, 1652129100, 1652215500, 1652301900, 1652388300, 1652820300, 1652906700, 1652993100, 1653079500, 1653338700, 1653425100, 1653511500, 1653597900, 1653684300, 1653943500, 1654029900, 1654116300, 1654202700, 1654289100, 1654548300, 1654634700, 1654721100, 1654807500, 1654893900, 1655153100, 1655239500, 1655325900, 1655412300, 1655498700, 1655671500, 1655757900, 1655844300, 1655930700, 1656017100, 1656103500, 1656276300, 1656362700, 1656449100, 1656535500, 1656621900, 1656708300, 1656881100, 1656967500, 1657053900, 1657140300, 1657226700, 1657313100, 1657572300, 1657658700, 1657745100, 1657831500, 1657917900, 1658090700, 1658177100, 1658263500, 1658349900, 1658436300, 1658522700, 1658695500, 1658781900, 1658868300, 1658954700, 1659041100, 1659127500, 1659300300, 1659386700, 1659473100, 1659559500, 1659645900, 1659732300, 1659905100, 1659991500, 1660077900, 1660164300, 1660250700, 1660509900, 1660
plot()
# Out:
# <Axes: xlabel='Date'>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
results = seasonal_decompose(df['Close'], model='additive', period=30)
results.plot()

# %%
def plot_graph(figsize, df_to_plot, column_name):
    # df_to_plot is already assumed to have 'Date' as its index
    df_to_plot = df_to_plot.sort_index()

    plt.figure(figsize=figsize)
    plt.plot(df_to_plot.index, df_to_plot[column_name], label=column_name)
    plt.title(f"NABIL {column_name} Over Time")
    plt.xlabel("Date")
    plt.ylabel(column_name)
    plt.legend()
    plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(df['Open'], label='Open Price')
plt.plot(df['Close'], label='Close Price')
plt.plot(df['High'], label='High Price')
plt.plot(df['Low'], label='Low Price')
plt.plot(df['Volume'], label='Volume')

# %%
df['MA_10'] = df['Close'].rolling(10).mean()
df['MA_20'] = df['Close'].rolling(20).mean()

# %%
print(df.isna().sum())
# Out:
# Open       0
# Close      0
# High       0
# Low        0
# Volume     0
# MA_10      9
# MA_20     19
# dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(df['Close'], label='Close Price')
plt.plot(df['MA_10'], label='MA 10')
plt.legend()
plt.title("Close Price vs 10-day Moving Average")
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['Close'], label='Close Price')
plt.plot(df['MA_20'], label='MA 20')
plt.legend()
plt.title("Close Price vs 20-day Moving Average")
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# %%
len(df)
# Out:
# 928

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 928 entries, 2022-01-17 to 2026-01-18
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    928 non-null    float64
#  1   Close   928 non-null    float64
#  2   High    928 non-null    float64
#  3   Low     928 non-null    float64
#  4   Volume  928 non-null    float64
#  5   MA_10   919 non-null    float64
#  6   MA_20   909 non-null    float64
# dtypes: float64(7)
# memory usage: 58.0 KB

# %%
def plot_graph(figsize, df_to_plot, column_name):

    plt.figure(figsize=figsize)
    plt.plot(df_to_plot.index, df_to_plot[column_name], label=column_name)
    plt.title(f"Siddhartha {column_name} Over Time")
    plt.xlabel("Date")
    plt.ylabel(column_name)
    plt.legend()
    plt.show()

# %%
import matplotlib.pyplot as plt
plot_graph((10, 5), df, "Close")

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import random
import os
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping

# %%
seed = 42
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)
os.environ["PYTHONHASHSEED"] = str(seed)

# %%
df = df[['Open','High','Low','Close','Volume']].copy()
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)

# stabilize volume
df['Volume'] = np.log1p(df['Volume'])

# %%
features = df[['Open','High','Low','Close','Volume']].values

# %%
window = 60
split = int(len(features) * 0.8)

train_raw = features[:split]
test_raw  = features[split - window:]

# %%
scaler_X = MinMaxScaler()
train_scaled = scaler_X.fit_transform(train_raw)
test_scaled  = scaler_X.transform(test_raw)

scaler_y = MinMaxScaler()
scaler_y.fit(train_raw[:, 3].reshape(-1, 1))  # Close
# Out:
# MinMaxScaler()

# %%
def create_sequences(data, window):
    X, y = [], []
    for i in range(window, len(data)):
        X.append(data[i-window:i])
        y.append(data[i, 3])  # Close
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.float32).reshape(-1,1)

# %%
X_train, y_train = create_sequences(train_scaled, window)
X_test, y_test   = create_sequences(test_scaled, window)

# %%
model_ohlcv = Sequential([
    LSTM(128, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.2),
    LSTM(64),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dense(1)
])

model_ohlcv.compile(optimizer=tf.keras.optimizers.Adam(0.001), loss='mse')
model_ohlcv.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_13 (LSTM)                  │ (None, 60, 128)        │        68,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 60, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_14 (LSTM)                  │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 122,241 (477.50 KB)
#  Trainable params: 122,241 (477.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stop = EarlyStopping(patience=10, restore_best_weights=True)

history = model_ohlcv.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=32,
    shuffle=False,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 8s 164ms/step - loss: 0.0575 - val_loss: 0.0295
# Epoch 2/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - loss: 0.0204 - val_loss: 0.0307
# Epoch 3/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.0144 - val_loss: 0.0253
# Epoch 4/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - loss: 0.0146 - val_loss: 0.0144
# Epoch 5/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.0127 - val_loss: 0.0079
# Epoch 6/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.0130 - val_loss: 0.0067
# Epoch 7/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0114 - val_loss: 0.0056
# Epoch 8/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 0.0096 - val_loss: 0.0061
# Epoch 9/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - loss: 0.0079 - val_loss: 0.0041
# Epoch 10/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.0083 - val_loss: 0.0037
# Epoch 11/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.0078 - val_loss: 0.0033
# Epoch 12/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.0070 - val_loss: 0.0039
# Epoch 13/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 205ms/step - loss: 0.0061 - val_loss: 0.0034
# Epoch 14/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.0064 - val_loss: 0.0037
# Epoch 15/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - loss: 0.0061 - val_loss: 0.0029
# Epoch 16/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 318ms/step - loss: 0.0062 - val_loss: 0.0029
# Epoch 17/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 176ms/step - loss: 0.0069 - val_loss: 0.0028
# Epoch 18/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - loss: 0.0063 - val_loss: 0.0035
# Epoch 19/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - loss: 0.0062 - val_loss: 0.0034
# Epoch 20/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 193ms/step - loss: 0.0055 - val_loss: 0.0027
# Epoch 21/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.0056 - val_loss: 0.0027
# Epoch 22/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0053 - val_loss: 0.0026
# Epoch 23/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.0061 - val_loss: 0.0062
# Epoch 24/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0063 - val_loss: 0.0040
# Epoch 25/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 244ms/step - loss: 0.0067 - val_loss: 0.0090
# Epoch 26/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 8s 137ms/step - loss: 0.0062 - val_loss: 0.0025
# Epoch 27/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 301ms/step - loss: 0.0060 - val_loss: 0.0074
# Epoch 28/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 8s 206ms/step - loss: 0.0060 - val_loss: 0.0062
# Epoch 29/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 252ms/step - loss: 0.0052 - val_loss: 0.0049
# Epoch 30/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 11s 292ms/step - loss: 0.0053 - val_loss: 0.0073
# Epoch 31/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - loss: 0.0052 - val_loss: 0.0042
# Epoch 32/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - loss: 0.0049 - val_loss: 0.0027
# Epoch 33/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 209ms/step - loss: 0.0045 - val_loss: 0.0064
# Epoch 34/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.0049 - val_loss: 0.0031
# Epoch 35/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.0044 - val_loss: 0.0047
# Epoch 36/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0040 - val_loss: 0.0020
# Epoch 37/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 207ms/step - loss: 0.0039 - val_loss: 0.0041
# Epoch 38/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.0039 - val_loss: 0.0021
# Epoch 39/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.0040 - val_loss: 0.0025
# Epoch 40/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0039 - val_loss: 0.0028
# Epoch 41/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 0.0043 - val_loss: 0.0019
# Epoch 42/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - loss: 0.0039 - val_loss: 0.0028
# Epoch 43/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 0.0033 - val_loss: 0.0019
# Epoch 44/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0035 - val_loss: 0.0024
# Epoch 45/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step - loss: 0.0035 - val_loss: 0.0028
# Epoch 46/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - loss: 0.0035 - val_loss: 0.0024
# Epoch 47/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.0034 - val_loss: 0.0027
# Epoch 48/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.0033 - val_loss: 0.0028
# Epoch 49/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0033 - val_loss: 0.0016
# Epoch 50/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.0030 - val_loss: 0.0016
# Epoch 51/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 52/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.0034 - val_loss: 0.0017
# Epoch 53/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.0031 - val_loss: 0.0017
# Epoch 54/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - loss: 0.0032 - val_loss: 0.0020
# Epoch 55/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - loss: 0.0032 - val_loss: 0.0016
# Epoch 56/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.0032 - val_loss: 0.0017
# Epoch 57/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.0027 - val_loss: 0.0019
# Epoch 58/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.0033 - val_loss: 0.0018
# Epoch 59/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - loss: 0.0028 - val_loss: 0.0014
# Epoch 60/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.0030 - val_loss: 0.0018
# Epoch 61/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0030 - val_loss: 0.0019
# Epoch 62/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - loss: 0.0031 - val_loss: 0.0020
# Epoch 63/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - loss: 0.0030 - val_loss: 0.0018
# Epoch 64/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 65/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 66/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.0029 - val_loss: 0.0015
# Epoch 67/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - loss: 0.0030 - val_loss: 0.0024
# Epoch 68/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 0.0029 - val_loss: 0.0014
# Epoch 69/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0030 - val_loss: 0.0016
# Epoch 70/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - loss: 0.0028 - val_loss: 0.0014
# Epoch 71/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.0027 - val_loss: 0.0014
# Epoch 72/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - loss: 0.0024 - val_loss: 0.0014
# Epoch 73/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0027 - val_loss: 0.0014
# Epoch 74/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.0025 - val_loss: 0.0014
# Epoch 75/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - loss: 0.0025 - val_loss: 0.0014
# Epoch 76/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.0024 - val_loss: 0.0014
# Epoch 77/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 78/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0026 - val_loss: 0.0014
# Epoch 79/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - loss: 0.0024 - val_loss: 0.0016
# Epoch 80/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - loss: 0.0025 - val_loss: 0.0013
# Epoch 81/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 82/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.0025 - val_loss: 0.0014
# Epoch 83/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0026 - val_loss: 0.0019
# Epoch 84/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step - loss: 0.0026 - val_loss: 0.0017
# Epoch 85/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 86/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.0026 - val_loss: 0.0016
# Epoch 87/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.0028 - val_loss: 0.0014
# Epoch 88/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 89/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 0.0028 - val_loss: 0.0016
# Epoch 90/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 91/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.0027 - val_loss: 0.0022

# %%
pred_scaled = model_ohlcv.predict(X_test)
pred = scaler_y.inverse_transform(pred_scaled)
actual = scaler_y.inverse_transform(y_test)

rmse = np.sqrt(mean_squared_error(actual, pred))
mae = mean_absolute_error(actual, pred)

print("RMSE:", rmse)
print("MAE :", mae)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step
# RMSE: 9.063120432695301
# MAE : 6.694967269897461

# %%
import plotly.graph_objects as go
import numpy as np

actual_flat = actual.flatten()
pred_flat = pred.flatten()

fig = go.Figure()

fig.add_trace(
    go.Scatter(
        y=actual_flat,
        mode="lines",
        name="Actual",
        line=dict(width=2)
    )
)

fig.add_trace(
    go.Scatter(
        y=pred_flat,
        mode="lines",
        name="Predicted",
        line=dict(
            width=2,
            shape="spline"
        )
    )
)

fig.update_layout(
    title="LSTM with OHLCV — Actual vs Predicted",
    xaxis_title="Time",
    yaxis_title="Price",
    hovermode="x unified",
    template="plotly_white"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4e732d81-712e-4316-8b4b-a73bfaeb9014" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e732d81-712e-4316-8b4b-a73bfaeb9014")) {                    Plotly.newPlot(                        "4e732d81-712e-4316-8b4b-a73bfaeb9014",                        [{"line":{"width":2},"mode":"lines","name":"Actual","y":[417.49002,409.32,412.01,401.64,405.53,413.38,415.41,416.35,416.69,416.24,413.08002,411.69,412.27002,412.85,414.30002,414.68002,417.23,425.19,420.93,420.19,419.56003,414.5,412.84,411.64,411.82,411.86002,414.36002,416.22,416.24,441.63,443.14,441.03998,429.0,430.38,423.42,424.39,427.03,427.03,432.35,440.49,435.15002,432.14,431.57,430.35,426.99,429.68,428.2,429.07,428.09,429.0,433.93002,440.78,442.79,464.82,459.92,468.82,458.89,456.2,458.03,450.73,444.38998,450.85,456.32,456.63998,466.97998,491.79,486.73,486.69,509.09,504.96,489.73,483.8,496.73,496.13998,490.92,489.38,498.6,511.59003,528.95996,549.81,547.37,564.79,570.68,563.64,565.29,561.95,556.39,556.41,552.93,554.91003,553.17,559.39,552.9,552.69,558.81,563.06,553.66,543.67,530.43,525.78,531.06
ff()
    gain = delta.clip(lower=0)
    loss = -delta.clip(upper=0)

    avg_gain = gain.rolling(14).mean()
    avg_loss = loss.rolling(14).mean()
    rs = avg_gain / avg_loss
    df['RSI'] = 100 - (100 / (1 + rs))

    ema12 = df['Close'].ewm(span=12, adjust=False).mean()
    ema26 = df['Close'].ewm(span=26, adjust=False).mean()
    df['MACD'] = ema12 - ema26

    return df

# %%
df_ind = add_indicators(df)
df_ind.dropna(inplace=True)
df_ind.reset_index(drop=True, inplace=True)

# %%
features_ind = df_ind[
    ['Open','High','Low','Close','Volume',
     'SMA_10','SMA_20','RSI','MACD']
].values

# %%
split = int(len(features_ind) * 0.8)
train_raw = features_ind[:split]
test_raw  = features_ind[split - window:]

# %%
scaler_X = MinMaxScaler()
train_scaled = scaler_X.fit_transform(train_raw)
test_scaled  = scaler_X.transform(test_raw)

scaler_y = MinMaxScaler()
scaler_y.fit(train_raw[:, 3].reshape(-1,1))
# Out:
# MinMaxScaler()

# %%
X_train, y_train = create_sequences(train_scaled, window)
X_test, y_test   = create_sequences(test_scaled, window)

# %%
print("X_train:", X_train.shape)
print("y_train:", y_train.shape)
print("X_test :", X_test.shape)
print("y_test :", y_test.shape)
# Out:
# X_train: (667, 60, 9)
# y_train: (667, 1)
# X_test : (182, 60, 9)
# y_test : (182, 1)

# %%
model = Sequential([
    LSTM(128, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.2),
    LSTM(64),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dense(1)
])

model.compile(optimizer=tf.keras.optimizers.Adam(0.001), loss="mse")


model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_15 (LSTM)                  │ (None, 60, 128)        │        70,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 60, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_16 (LSTM)                  │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 124,289 (485.50 KB)
#  Trainable params: 124,289 (485.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=32,
    shuffle=False,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 143ms/step - loss: 0.0652 - val_loss: 0.0704
# Epoch 2/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 180ms/step - loss: 0.0219 - val_loss: 0.0513
# Epoch 3/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - loss: 0.0186 - val_loss: 0.0208
# Epoch 4/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0212 - val_loss: 0.0186
# Epoch 5/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0182 - val_loss: 0.0134
# Epoch 6/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - loss: 0.0165 - val_loss: 0.0158
# Epoch 7/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - loss: 0.0136 - val_loss: 0.0129
# Epoch 8/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0109 - val_loss: 0.0126
# Epoch 9/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0091 - val_loss: 0.0081
# Epoch 10/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0094 - val_loss: 0.0078
# Epoch 11/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step - loss: 0.0077 - val_loss: 0.0065
# Epoch 12/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.0083 - val_loss: 0.0051
# Epoch 13/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.0080 - val_loss: 0.0075
# Epoch 14/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0071 - val_loss: 0.0051
# Epoch 15/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - loss: 0.0081 - val_loss: 0.0044
# Epoch 16/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 162ms/step - loss: 0.0082 - val_loss: 0.0045
# Epoch 17/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.0081 - val_loss: 0.0046
# Epoch 18/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 0.0079 - val_loss: 0.0040
# Epoch 19/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.0083 - val_loss: 0.0038
# Epoch 20/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - loss: 0.0076 - val_loss: 0.0040
# Epoch 21/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.0076 - val_loss: 0.0035
# Epoch 22/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.0075 - val_loss: 0.0037
# Epoch 23/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.0073 - val_loss: 0.0034
# Epoch 24/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 0.0077 - val_loss: 0.0037
# Epoch 25/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - loss: 0.0071 - val_loss: 0.0032
# Epoch 26/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0060 - val_loss: 0.0031
# Epoch 27/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0062 - val_loss: 0.0030
# Epoch 28/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.0056 - val_loss: 0.0031
# Epoch 29/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 179ms/step - loss: 0.0055 - val_loss: 0.0029
# Epoch 30/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0055 - val_loss: 0.0028
# Epoch 31/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - loss: 0.0052 - val_loss: 0.0030
# Epoch 32/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0045 - val_loss: 0.0027
# Epoch 33/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.0047 - val_loss: 0.0027
# Epoch 34/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - loss: 0.0047 - val_loss: 0.0026
# Epoch 35/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.0048 - val_loss: 0.0026
# Epoch 36/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0048 - val_loss: 0.0026
# Epoch 37/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.0046 - val_loss: 0.0030
# Epoch 38/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 161ms/step - loss: 0.0046 - val_loss: 0.0024
# Epoch 39/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 0.0045 - val_loss: 0.0027
# Epoch 40/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - loss: 0.0044 - val_loss: 0.0028
# Epoch 41/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.0049 - val_loss: 0.0024
# Epoch 42/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - loss: 0.0048 - val_loss: 0.0026
# Epoch 43/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - loss: 0.0049 - val_loss: 0.0024
# Epoch 44/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0050 - val_loss: 0.0022
# Epoch 45/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.0039 - val_loss: 0.0024
# Epoch 46/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0049 - val_loss: 0.0022
# Epoch 47/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - loss: 0.0040 - val_loss: 0.0025
# Epoch 48/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - loss: 0.0041 - val_loss: 0.0028
# Epoch 49/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - loss: 0.0042 - val_loss: 0.0022
# Epoch 50/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - loss: 0.0043 - val_loss: 0.0020
# Epoch 51/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - loss: 0.0041 - val_loss: 0.0020
# Epoch 52/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 53/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0036 - val_loss: 0.0019
# Epoch 54/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - loss: 0.0036 - val_loss: 0.0024
# Epoch 55/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - loss: 0.0039 - val_loss: 0.0020
# Epoch 56/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - loss: 0.0039 - val_loss: 0.0021
# Epoch 57/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.0031 - val_loss: 0.0019
# Epoch 58/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0040 - val_loss: 0.0019
# Epoch 59/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.0031 - val_loss: 0.0019
# Epoch 60/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - loss: 0.0034 - val_loss: 0.0018
# Epoch 61/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 0.0032 - val_loss: 0.0022
# Epoch 62/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0043 - val_loss: 0.0027
# Epoch 63/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.0033 - val_loss: 0.0018
# Epoch 64/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - loss: 0.0038 - val_loss: 0.0023
# Epoch 65/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0029 - val_loss: 0.0021
# Epoch 66/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - loss: 0.0034 - val_loss: 0.0021
# Epoch 67/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0035 - val_loss: 0.0017
# Epoch 68/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0033 - val_loss: 0.0021
# Epoch 69/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 192ms/step - loss: 0.0035 - val_loss: 0.0028
# Epoch 70/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.0039 - val_loss: 0.0021
# Epoch 71/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0032 - val_loss: 0.0018
# Epoch 72/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0035 - val_loss: 0.0016
# Epoch 73/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 74/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step - loss: 0.0031 - val_loss: 0.0016
# Epoch 75/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.0032 - val_loss: 0.0016
# Epoch 76/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - loss: 0.0031 - val_loss: 0.0016
# Epoch 77/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 315ms/step - loss: 0.0027 - val_loss: 0.0021
# Epoch 78/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 6s 260ms/step - loss: 0.0030 - val_loss: 0.0017
# Epoch 79/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 154ms/step - loss: 0.0033 - val_loss: 0.0016
# Epoch 80/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 81/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - loss: 0.0030 - val_loss: 0.0018
# Epoch 82/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 83/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0031 - val_loss: 0.0015
# Epoch 84/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - loss: 0.0027 - val_loss: 0.0019
# Epoch 85/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 0.0030 - val_loss: 0.0019
# Epoch 86/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - loss: 0.0030 - val_loss: 0.0025
# Epoch 87/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0032 - val_loss: 0.0019
# Epoch 88/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 204ms/step - loss: 0.0033 - val_loss: 0.0018
# Epoch 89/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 6s 252ms/step - loss: 0.0024 - val_loss: 0.0017
# Epoch 90/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.0026 - val_loss: 0.0016
# Epoch 91/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.0029 - val_loss: 0.0017
# Epoch 92/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - loss: 0.0029 - val_loss: 0.0017
# Epoch 93/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 6s 161ms/step - loss: 0.0030 - val_loss: 0.0022

# %%
pred = scaler_y.inverse_transform(model.predict(X_test))
actual = scaler_y.inverse_transform(y_test)

rmse = np.sqrt(mean_squared_error(actual, pred))
mae = mean_absolute_error(actual, pred)

print("RMSE with indicators:", rmse)
print("MAE with indicators :", mae)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step
# RMSE with indicators: 9.023957050113058
# MAE with indicators : 6.630553722381592

# %%
plt.figure(figsize=(12, 6))
plt.plot(actual, color='blue', label='Actual Close Price')
plt.plot(pred, color='red', label='Predicted Close Price')
plt.title('Multi-feature LSTM Stock Close Price Prediction')
plt.xlabel('Time (Test Data Index)')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %%
model.save("model_close_lstm.h5")
